# %%
#Including libraries
import pandas as pd
import numpy as np
import re
import csv

# %%
ukraine_df = pd.read_csv('../Final_Project/Datasets/Ukraine_Key_Figures.csv')

# %%
ukraine_df.head()
# Out:
#                      Flash Appeal                     Unnamed: 1  \
# 0  Total Population(Flash Appeal)  People Affected(Flash Appeal)
# 1                        41400000                       18000000
# 2                        41400000                       18000000
# 3                        41400000                       18000000
# 4                        41400000                       18000000
#
#                Unnamed: 2                    Unnamed: 3  Unnamed: 4  \
# 0  People Affected - IDPs  People in Need(Flash Appeal)  PiN - IDPs
# 1                 6700000                      12000000     4300000
# 2                 6700000                      12000000     4300000
# 3                 6700000                      12000000     4300000
# 4                 6700000                      12000000     4300000
#
#                       Unnamed: 5              Unnamed: 6  \
# 0  People Targeted(Flash Appeal)  People Targeted - IDPs
# ...

# %%
ukraine_df.shape
# Out:
# (16, 30)
